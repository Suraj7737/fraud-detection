# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('AIML Dataset.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['type'].value_counts().plot(kind='bar',title='trensection types')
plt.xlabel('trensection types')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
fraud_by_type =df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_by_type.plot(kind='bar',title='fraud by types')
# Out:
# <Axes: title={'center': 'fraud by types'}, xlabel='type'>

# %%
sns.histplot(np.log1p(df['amount']),bins=100,kde=True,color='red')
plt.title('log 1 scaled')
plt.xlabel('log(amount + 1)')
plt.show()

# %%
plt.scatter(df['isFlaggedFraud'],df['isFraud'])
plt.show()

# %% [markdown]
# ### our data is left squed so we use boxplot to find outliers

# %%
sns.boxplot(data = df[df['amount']<50000],x='isFraud',y='amount')
plt.title('amount vs isfruad ')
# Out:
# Text(0.5, 1.0, 'amount vs isfruad ')

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df['balanceDiffOreginal'] = df['oldbalanceOrg'] - df['newbalanceOrig']
df['balanceDiffDist'] = df['oldbalanceDest'] - df['newbalanceDest']

# %%
(df['balanceDiffOreginal']  < 0).sum()
# Out:
# np.int64(1399253)

# %%
df.drop(columns=['step'],inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOreginal  balanceDiffDist
# 0              9839.64              0.0
# 1              1864.28              0.0
# ...

# %%
top_senders = df['nameOrig'].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_resiver = df['nameDest'].value_counts().head(10)

# %%
top_resiver
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df['isFraud']==1]['nameOrig'].value_counts().head(10)

# %%
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
corr = df[['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest','isFraud']].corr()

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balanceDiffOreginal', 'balanceDiffDist'],
#       dtype='str')

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt='.2f')
plt.show('corelation matrix')

# %%
zero_after_transfer = df[
    (df['oldbalanceOrg']>0)&
    (df['newbalanceOrig']==0)
]

# %% [markdown]
# # Feature engineering

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOreginal  balanceDiffDist
# 0              9839.64              0.0
# 1              1864.28              0.0
# ...

# %%
df_model = df.drop(columns=['nameOrig','nameDest','isFlaggedFraud','balanceDiffOreginal','balanceDiffDist'],axis=0)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud
# 0             0.0        0
# 1             0.0        0
# 2             0.0        1
# 3             0.0        1
# 4             0.0        0

# %%
numerical = df_model.iloc[:,1:6]
categorical = df_model.iloc[:,0:1]

# %%
y = df['isFraud']
x = df.drop(columns=['isFraud'],axis=0)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify=y)

# %%
preprocesser = ColumnTransformer(transformers=[
    ('num',StandardScaler(),['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']),
    ('categorical',OneHotEncoder(drop='first'),['type'])
],remainder='drop')

# %%
pipe = Pipeline([
    ('pre',preprocesser),
    ('mod',LogisticRegression(class_weight='balanced',max_iter=1000))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('categorical',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('mod',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipe.predict(x_test)

# %%
y_pred = pd.DataFrame(y_pred)

# %%
y_test
# Out:
# 4205987    0
# 5982680    0
# 6101673    0
# 5889352    0
# 5968374    0
#           ..
# 1828628    0
# 5675605    0
# 4709565    0
# 4776738    0
# 4438156    0
# Name: isFraud, Length: 1272524, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9454697907465792

# %%
import joblib

# %%
joblib.dump(pipe,'fruad_detection_pipeline.pkl')
# Out:
# ['fruad_detection_pipeline.pkl']
